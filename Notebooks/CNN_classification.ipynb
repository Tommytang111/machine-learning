# %% [markdown]
# # Training a CNN for a real-world Image Classification Task
#
# This is an example of defining and training a CNN to deal with a real-world image classification. These are images taken by numerous amatuer photgraphers, in multiple cameras and lightening conditions.
#
# We will show:
# 1. How a relatively shallow CNN with 5 convolution layers and about 1 million parameters can defined in a dozen lines of code, and trained for 30m on a CPU (or ~3m on a GPU), to achieve reasnoble accuracy for classifying real-world images (74.3%).
# 2. We will see, that getting to good results on relatively small training data (1000 samples per class in a binary classification task) can be greatly improved by introducing **data augmentation** and **dropout**. This will set the accuracy at 81.7%. This is just the beginning - training a larger network with more data could easily increase the accuracy. Fine-tunning a large CNN pre-trained on other images, and fine-tuned on the same small dataset - is an excellent way to increase the accuracy further.
# 3. We will use the `dataset` API, that was introduced in a previous notebook.
#
# Here we are following Chollet Deep Learning with Python, chapter 8. The code was adapted for its Github notebook based on the Apache 2.0 license.

# %%
from tensorflow import keras
from tensorflow.keras import layers
import pathlib
from tensorflow.keras.utils import image_dataset_from_directory
import matplotlib.pyplot as plt
# Out:
# 2025-03-18 13:49:54.285767: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742320194.295508   27575 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742320194.298287   27575 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-18 13:49:54.308940: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# Download the data and extract

# %%
#Use Kaggle API to download and extract zip files
kaggle competitions download -c dogs-vs-cats

# %% [markdown]
# Rearrange data into new folders:

# %%
import os, shutil, pathlib

original_dir = pathlib.Path("./Data/train")
new_base_dir = pathlib.Path("./Data/kaggle_dogs_vs_cats_small")

def make_subset(subset_name, start_index, end_index):
    for category in ("cat", "dog"):
        dir = new_base_dir / subset_name / category
        os.makedirs(dir)
        fnames = [f"{category}.{i}.jpg" for i in range(start_index, end_index)]
        for fname in fnames:
            shutil.copyfile(src=original_dir / fname,
                            dst=dir / fname)

make_subset("train", start_index=0, end_index=1000)
make_subset("validation", start_index=1000, end_index=1500)
make_subset("test", start_index=1500, end_index=2500)

# %% [markdown]
# Load the data into three sets:

# %%
# This should point to the small dataset of the Kaggle Dogs vs Cats competition that was created in a previous notebook
data_folder = pathlib.Path('./Data/kaggle_dogs_vs_cats_small')

# %%
train_dataset = image_dataset_from_directory(
    data_folder / "train",
    image_size=(180, 180),
    batch_size=32)

validation_dataset = image_dataset_from_directory(
    data_folder / "validation",
    image_size=(180, 180),
    batch_size=32)

test_dataset = image_dataset_from_directory(
    data_folder / "test",
    image_size=(180, 180),
    batch_size=32)
# Out:
# Found 2000 files belonging to 2 classes.
# I0000 00:00:1742320800.130247   27575 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5564 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:01:00.0, compute capability: 8.6
# Found 1000 files belonging to 2 classes.
# Found 2000 files belonging to 2 classes.

# %% [markdown]
# ### Defining the model

# %%
inputs = keras.Input(shape=(180, 180, 3))

x = layers.Rescaling(1./255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)

model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 178, 178, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 89, 89, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 87, 87, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 43, 43, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 41, 41, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 20, 20, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 18, 18, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 9, 9, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 7, 7, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 12544)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │        12,545 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 991,041 (3.78 MB)
#  Trainable params: 991,041 (3.78 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"]) #MSE:Mean square Error

# %% [markdown]
# Note that running the training on a CPU could take about 30 minutes.

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="../models/convnet_from_scratch.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1742321111.925808   28594 service.cc:148] XLA service 0x7f9f5400a260 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1742321111.925883   28594 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 3070, Compute Capability 8.6
# 2025-03-18 14:05:11.949943: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1742321112.071872   28594 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  6/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.5840 - loss: 0.7183
# I0000 00:00:1742321115.221338   28594 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 82ms/step - accuracy: 0.5399 - loss: 0.7660 - val_accuracy: 0.5020 - val_loss: 0.6914
# Epoch 2/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.5281 - loss: 0.6941 - val_accuracy: 0.5000 - val_loss: 0.7037
# Epoch 3/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.5318 - loss: 0.6908 - val_accuracy: 0.5190 - val_loss: 0.6952
# Epoch 4/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.5695 - loss: 0.6835 - val_accuracy: 0.5250 - val_loss: 0.7014
# Epoch 5/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.6011 - loss: 0.6663 - val_accuracy: 0.6760 - val_loss: 0.6001
# Epoch 6/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.6696 - loss: 0.6106 - val_accuracy: 0.5850 - val_loss: 0.6559
# Epoch 7/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.6969 - loss: 0.5859 - val_accuracy: 0.6080 - val_loss: 0.7126
# Epoch 8/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.7105 - loss: 0.5662 - val_accuracy: 0.6780 - val_loss: 0.5856
# Epoch 9/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.7050 - loss: 0.5582 - val_accuracy: 0.6840 - val_loss: 0.5958
# Epoch 10/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.7372 - loss: 0.5206 - val_accuracy: 0.6960 - val_loss: 0.5701
# Epoch 11/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.7677 - loss: 0.4673 - val_accuracy: 0.7140 - val_loss: 0.5716
# Epoch 12/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.8030 - loss: 0.4304 - val_accuracy: 0.7460 - val_loss: 0.5645
# Epoch 13/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8217 - loss: 0.3891 - val_accuracy: 0.7170 - val_loss: 0.7131
# Epoch 14/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8476 - loss: 0.3404 - val_accuracy: 0.7420 - val_loss: 0.6211
# Epoch 15/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.8841 - loss: 0.2985 - val_accuracy: 0.7390 - val_loss: 0.7709
# Epoch 16/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8901 - loss: 0.2655 - val_accuracy: 0.7450 - val_loss: 0.8912
# Epoch 17/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9128 - loss: 0.2149 - val_accuracy: 0.7450 - val_loss: 0.7883
# Epoch 18/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9378 - loss: 0.1737 - val_accuracy: 0.7300 - val_loss: 0.9606
# Epoch 19/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9397 - loss: 0.1439 - val_accuracy: 0.7290 - val_loss: 1.0232
# Epoch 20/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9483 - loss: 0.1435 - val_accuracy: 0.7390 - val_loss: 1.1358
# Epoch 21/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9550 - loss: 0.1076 - val_accuracy: 0.7380 - val_loss: 1.1381
# Epoch 22/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9736 - loss: 0.0650 - val_accuracy: 0.7050 - val_loss: 1.3776
# Epoch 23/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9722 - loss: 0.0736 - val_accuracy: 0.7430 - val_loss: 1.2464
# Epoch 24/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9796 - loss: 0.0587 - val_accuracy: 0.7320 - val_loss: 1.5024
# Epoch 25/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9836 - loss: 0.0514 - val_accuracy: 0.7150 - val_loss: 1.5469
# Epoch 26/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9759 - loss: 0.0808 - val_accuracy: 0.7360 - val_loss: 1.4857
# Epoch 27/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9792 - loss: 0.0871 - val_accuracy: 0.7450 - val_loss: 1.5329
# Epoch 28/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9841 - loss: 0.0476 - val_accuracy: 0.7390 - val_loss: 1.5377
# Epoch 29/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9929 - loss: 0.0369 - val_accuracy: 0.7460 - val_loss: 1.5664
# Epoch 30/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9877 - loss: 0.0457 - val_accuracy: 0.7280 - val_loss: 1.9599

# %% [markdown]
# **Displaying curves of loss and accuracy during training**

# %%
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# Overfitting is evident, around epoch 12.

# %% [markdown]
# **Evaluating the model on the test set**

# %%
test_model = keras.models.load_model("../models/convnet_from_scratch.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.7393 - loss: 0.6590
# Test accuracy: 0.730

# %% [markdown]
# ### Using data augmentation

# %% [markdown]
# **Define a data augmentation stage to add to an image model**

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

# %% [markdown]
# See the Keras documentation to see what each method does. Notice that the augmentations are defined as a sequential model.

# %% [markdown]
# **Displaying some randomly augmented training images**

# %% [markdown]
# Here we use the `data_augmentation` model that we defined above, and pass the same image nine times.
# Can you identify the three augmenting effects?

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")
# Out:
# 2025-03-18 14:28:59.599464: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# **Defining a new convnet that includes image augmentation and dropout**

# %% [markdown]
# Our new model includes two changes compared to the previous one:
# 1. data augmentation as the first step
# 2. a dropout layer just before the last layer for regularization

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential (Sequential)         │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling_1 (Rescaling)         │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 178, 178, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 89, 89, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 87, 87, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 43, 43, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 41, 41, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 20, 20, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 18, 18, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 9, 9, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 7, 7, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 12544)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 12544)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │        12,545 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 991,041 (3.78 MB)
#  Trainable params: 991,041 (3.78 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Notice that the number of parameters is the same as the previous model.

# %% [markdown]
# **Training the regularized convnet**

# %% [markdown]
# Here we train for 100 epochs, compared to 30 before. Since the previous model overfitted after about 12 epoches, this discrepency still allows one to reasonably compare the performance of the two models.

# %% [markdown]
# Note: running the training on a CPU will take about 2 hours.

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="./models/convnet_from_scratch_with_augmentation.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=100,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.5062 - loss: 0.7101 - val_accuracy: 0.5000 - val_loss: 0.6939
# Epoch 2/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5008 - loss: 0.6940 - val_accuracy: 0.5000 - val_loss: 0.6927
# Epoch 3/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.5036 - loss: 0.6936 - val_accuracy: 0.5580 - val_loss: 0.6901
# Epoch 4/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.5600 - loss: 0.6923 - val_accuracy: 0.5540 - val_loss: 0.6885
# Epoch 5/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.5823 - loss: 0.6821 - val_accuracy: 0.5280 - val_loss: 0.8041
# Epoch 6/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.6086 - loss: 0.6772 - val_accuracy: 0.6210 - val_loss: 0.6337
# Epoch 7/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.6594 - loss: 0.6291 - val_accuracy: 0.5940 - val_loss: 0.6827
# Epoch 8/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.6308 - loss: 0.6482 - val_accuracy: 0.6140 - val_loss: 0.6958
# Epoch 9/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.6773 - loss: 0.5941 - val_accuracy: 0.6250 - val_loss: 0.6684
# Epoch 10/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.6852 - loss: 0.5980 - val_accuracy: 0.6410 - val_loss: 0.6296
# Epoch 11/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.6907 - loss: 0.5858 - val_accuracy: 0.6410 - val_loss: 0.6551
# Epoch 12/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.6912 - loss: 0.5959 - val_accuracy: 0.6810 - val_loss: 0.5748
# Epoch 13/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.7136 - loss: 0.5666 - val_accuracy: 0.6750 - val_loss: 0.5898
# Epoch 14/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.7276 - loss: 0.5645 - val_accuracy: 0.7050 - val_loss: 0.5919
# Epoch 15/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.7005 - loss: 0.5577 - val_accuracy: 0.6130 - val_loss: 0.9021
# Epoch 16/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.7026 - loss: 0.5575 - val_accuracy: 0.6200 - val_loss: 0.9357
# Epoch 17/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.7411 - loss: 0.5443 - val_accuracy: 0.6550 - val_loss: 0.7287
# Epoch 18/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.7203 - loss: 0.5562 - val_accuracy: 0.6740 - val_loss: 0.5684
# Epoch 19/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.7355 - loss: 0.5264 - val_accuracy: 0.7200 - val_loss: 0.5650
# Epoch 20/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.7435 - loss: 0.5263 - val_accuracy: 0.7420 - val_loss: 0.5176
# Epoch 21/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.7542 - loss: 0.4897 - val_accuracy: 0.7030 - val_loss: 0.5406
# Epoch 22/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.7663 - loss: 0.4964 - val_accuracy: 0.7550 - val_loss: 0.4964
# Epoch 23/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.7755 - loss: 0.4616 - val_accuracy: 0.7140 - val_loss: 0.5777
# Epoch 24/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.7651 - loss: 0.4839 - val_accuracy: 0.6960 - val_loss: 0.6644
# Epoch 25/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.7706 - loss: 0.4944 - val_accuracy: 0.7440 - val_loss: 0.5638
# Epoch 26/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.7947 - loss: 0.4630 - val_accuracy: 0.7480 - val_loss: 0.5662
# Epoch 27/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.7873 - loss: 0.4699 - val_accuracy: 0.7890 - val_loss: 0.4526
# Epoch 28/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8117 - loss: 0.4263 - val_accuracy: 0.7500 - val_loss: 0.5291
# Epoch 29/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.7721 - loss: 0.4849 - val_accuracy: 0.7280 - val_loss: 0.5972
# Epoch 30/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8032 - loss: 0.4349 - val_accuracy: 0.8050 - val_loss: 0.4921
# Epoch 31/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.7916 - loss: 0.4309 - val_accuracy: 0.7840 - val_loss: 0.4724
# Epoch 32/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8190 - loss: 0.4048 - val_accuracy: 0.8000 - val_loss: 0.4500
# Epoch 33/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8176 - loss: 0.3985 - val_accuracy: 0.7950 - val_loss: 0.5396
# Epoch 34/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.8135 - loss: 0.4189 - val_accuracy: 0.7330 - val_loss: 0.6214
# Epoch 35/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.7909 - loss: 0.4334 - val_accuracy: 0.7910 - val_loss: 0.4831
# Epoch 36/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.8303 - loss: 0.3879 - val_accuracy: 0.8070 - val_loss: 0.4430
# Epoch 37/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.8358 - loss: 0.3783 - val_accuracy: 0.7440 - val_loss: 0.5818
# Epoch 38/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.8114 - loss: 0.3946 - val_accuracy: 0.8200 - val_loss: 0.4415
# Epoch 39/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.8419 - loss: 0.3765 - val_accuracy: 0.7610 - val_loss: 0.6810
# Epoch 40/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.8318 - loss: 0.4054 - val_accuracy: 0.8360 - val_loss: 0.4372
# Epoch 41/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.8461 - loss: 0.3529 - val_accuracy: 0.8210 - val_loss: 0.4411
# Epoch 42/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8500 - loss: 0.3608 - val_accuracy: 0.8180 - val_loss: 0.4722
# Epoch 43/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8431 - loss: 0.3485 - val_accuracy: 0.8260 - val_loss: 0.4756
# Epoch 44/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8480 - loss: 0.3220 - val_accuracy: 0.7900 - val_loss: 0.4884
# Epoch 45/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8598 - loss: 0.3303 - val_accuracy: 0.8120 - val_loss: 0.5071
# Epoch 46/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8615 - loss: 0.3024 - val_accuracy: 0.8320 - val_loss: 0.5321
# Epoch 47/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.8564 - loss: 0.3280 - val_accuracy: 0.8220 - val_loss: 0.4178
# Epoch 48/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.8808 - loss: 0.3178 - val_accuracy: 0.8370 - val_loss: 0.4870
# Epoch 49/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.8711 - loss: 0.3089 - val_accuracy: 0.7840 - val_loss: 0.6659
# Epoch 50/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.8580 - loss: 0.3406 - val_accuracy: 0.7030 - val_loss: 0.8080
# Epoch 51/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.8597 - loss: 0.3194 - val_accuracy: 0.8240 - val_loss: 0.4191
# Epoch 52/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.8947 - loss: 0.2695 - val_accuracy: 0.8000 - val_loss: 0.5848
# Epoch 53/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.8711 - loss: 0.2936 - val_accuracy: 0.7810 - val_loss: 0.6038
# Epoch 54/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.8792 - loss: 0.2854 - val_accuracy: 0.7620 - val_loss: 0.8064
# Epoch 55/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.8844 - loss: 0.2645 - val_accuracy: 0.8090 - val_loss: 0.5390
# Epoch 56/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.8886 - loss: 0.2594 - val_accuracy: 0.8310 - val_loss: 0.4469
# Epoch 57/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.8967 - loss: 0.2525 - val_accuracy: 0.8430 - val_loss: 0.4242
# Epoch 58/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.8942 - loss: 0.2522 - val_accuracy: 0.8340 - val_loss: 0.5018
# Epoch 59/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.8978 - loss: 0.2390 - val_accuracy: 0.8310 - val_loss: 0.4865
# Epoch 60/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.8867 - loss: 0.2793 - val_accuracy: 0.8430 - val_loss: 0.5249
# Epoch 61/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9082 - loss: 0.2316 - val_accuracy: 0.8450 - val_loss: 0.4621
# Epoch 62/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9137 - loss: 0.2226 - val_accuracy: 0.8420 - val_loss: 0.5265
# Epoch 63/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9123 - loss: 0.2194 - val_accuracy: 0.8330 - val_loss: 0.4312
# Epoch 64/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9004 - loss: 0.2337 - val_accuracy: 0.8480 - val_loss: 0.4611
# Epoch 65/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9079 - loss: 0.2230 - val_accuracy: 0.8340 - val_loss: 0.4557
# Epoch 66/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9160 - loss: 0.2173 - val_accuracy: 0.7520 - val_loss: 0.7925
# Epoch 67/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9122 - loss: 0.2207 - val_accuracy: 0.8090 - val_loss: 0.7210
# Epoch 68/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9113 - loss: 0.2167 - val_accuracy: 0.8410 - val_loss: 0.6313
# Epoch 69/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9163 - loss: 0.2089 - val_accuracy: 0.8190 - val_loss: 0.6391
# Epoch 70/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9147 - loss: 0.2358 - val_accuracy: 0.8470 - val_loss: 0.5402
# Epoch 71/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9221 - loss: 0.2204 - val_accuracy: 0.8340 - val_loss: 0.4511
# Epoch 72/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9232 - loss: 0.1895 - val_accuracy: 0.8430 - val_loss: 0.4925
# Epoch 73/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9257 - loss: 0.1842 - val_accuracy: 0.8430 - val_loss: 0.4761
# Epoch 74/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9048 - loss: 0.2171 - val_accuracy: 0.7960 - val_loss: 0.8311
# Epoch 75/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9290 - loss: 0.1623 - val_accuracy: 0.8150 - val_loss: 1.1290
# Epoch 76/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9280 - loss: 0.1913 - val_accuracy: 0.8350 - val_loss: 0.5386
# Epoch 77/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9163 - loss: 0.2374 - val_accuracy: 0.8350 - val_loss: 0.5747
# Epoch 78/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9313 - loss: 0.1856 - val_accuracy: 0.8180 - val_loss: 0.6863
# Epoch 79/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9093 - loss: 0.2045 - val_accuracy: 0.8570 - val_loss: 0.5167
# Epoch 80/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9290 - loss: 0.1804 - val_accuracy: 0.8150 - val_loss: 0.6033
# Epoch 81/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9303 - loss: 0.1701 - val_accuracy: 0.8260 - val_loss: 0.5145
# Epoch 82/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9415 - loss: 0.1539 - val_accuracy: 0.8230 - val_loss: 0.6694
# Epoch 83/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9219 - loss: 0.1802 - val_accuracy: 0.8500 - val_loss: 0.5313
# Epoch 84/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9432 - loss: 0.1583 - val_accuracy: 0.8130 - val_loss: 0.7760
# Epoch 85/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9208 - loss: 0.2025 - val_accuracy: 0.8330 - val_loss: 0.7660
# Epoch 86/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9246 - loss: 0.1865 - val_accuracy: 0.8390 - val_loss: 0.6174
# Epoch 87/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9370 - loss: 0.1591 - val_accuracy: 0.7560 - val_loss: 1.3593
# Epoch 88/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9117 - loss: 0.2253 - val_accuracy: 0.7740 - val_loss: 1.1990
# Epoch 89/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9240 - loss: 0.2125 - val_accuracy: 0.8010 - val_loss: 0.8205
# Epoch 90/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9323 - loss: 0.1672 - val_accuracy: 0.8430 - val_loss: 0.5869
# Epoch 91/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9274 - loss: 0.1731 - val_accuracy: 0.8310 - val_loss: 0.8373
# Epoch 92/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9407 - loss: 0.1726 - val_accuracy: 0.8160 - val_loss: 0.6740
# Epoch 93/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9374 - loss: 0.1521 - val_accuracy: 0.8260 - val_loss: 0.8205
# Epoch 94/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9550 - loss: 0.1286 - val_accuracy: 0.8700 - val_loss: 0.9460
# Epoch 95/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9397 - loss: 0.1753 - val_accuracy: 0.8250 - val_loss: 1.4427
# Epoch 96/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9437 - loss: 0.1555 - val_accuracy: 0.8110 - val_loss: 0.9244
# Epoch 97/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9266 - loss: 0.1876 - val_accuracy: 0.8550 - val_loss: 0.6272
# Epoch 98/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9496 - loss: 0.1410 - val_accuracy: 0.8290 - val_loss: 0.7441
# Epoch 99/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9470 - loss: 0.1770 - val_accuracy: 0.8600 - val_loss: 0.7081
# Epoch 100/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9371 - loss: 0.2117 - val_accuracy: 0.7770 - val_loss: 0.8645

# %% [markdown]
# **Evaluating the model on the test set**

# %% [markdown]
# Note the data augmentation and dropout are applied only during training, not during inference.

# %%
test_model = keras.models.load_model(
    "./models/convnet_from_scratch_with_augmentation.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8137 - loss: 0.4651
# Test accuracy: 0.814

# %%
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# Here an overfit is much less evident. Based on the validation accuracy it might have been reached only towards the last few epoches. Though the vaidation loss, while noisy, starts to increase after the 50th epoch or so.
